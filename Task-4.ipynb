# %%
#importing libraries

import cv2
import numpy as np
import matplotlib.pyplot as plot

# %% [markdown]
# ## Task 4.1
#
# ==>Create image by yourself Using Python Code

# %%
image = np.zeros(shape=(350,350,3)).astype('uint8')

# %%
plot.imshow(image)

# %%
image[:] = ( 135,206,235 )

# %%
# grass
# image[250:,:,:] = (0,255,0)

# %%
image[0:150,:,:] = (255,179,102)

# %%
plot.imshow(image)

# %%
plot.imshow(cv2.ellipse(image,(50,50),(25,25),25,180,360,(0,0,0),4))
plot.imshow(cv2.ellipse(image,(100,50),(25,25),-25,180,360,(0,0,0),4))
plot.imshow(cv2.ellipse(image,(150,90),(25,25),25,180,360,(0,0,0),4))
plot.imshow(cv2.ellipse(image,(200,90),(25,25),-25,180,360,(0,0,0),4))

# %%
plot.imshow(image)

# %%
plot.imshow(cv2.circle(image,(280,60),50,(255,255,0),-1))

# %%
# plot.imshow(cv2.putText(image.copy(),"S",(0,250),500,cv2.FONT_HERSHEY_SCRIPT_COMPLEX,(0,0,0),10))

# %%
plot.imshow(cv2.ellipse(image,(0,400),(350,150),0,180,360,(249,228,183),-1))

# %%
# plot.imshow(cv2.ellipse(image.copy(),(0,400),(350,150),90,8,360,(249,228,183),-1))

# %%
plot.imshow(cv2.fillPoly(image,[np.array([[300,200],[275,150],[250,200]])],(255,255,255)))

# %%
plot.imshow(cv2.fillPoly(image,[np.array([[200,200],[225,225],[275,225],[300,200]])],(102,34,0)))

# %%
plot.imshow(cv2.circle(image,(125,225),12,(0,0,0),-1))

# %%
plot.imshow(cv2.polylines(image,[np.array([[125,225],[125,279],[100,300],[125,279],[150,300],[125,279],[125,255],[155,225],[125,255],[90,225],[125,255],[155,222]])],False,(0,0,0),3))

# %%
cv2.cvtColor(image,cv2.COLOR_RGB2BGR)
# Out:
# array([[[102, 179, 255],
#         [102, 179, 255],
#         [102, 179, 255],
#         ...,
#         [102, 179, 255],
#         [102, 179, 255],
#         [102, 179, 255]],
#
#        [[102, 179, 255],
#         [102, 179, 255],
#         [102, 179, 255],
#         ...,
#         [102, 179, 255],
#         [102, 179, 255],
#         [102, 179, 255]],
#
#        [[102, 179, 255],
#         [102, 179, 255],
#         [102, 179, 255],
#         ...,
#         [102, 179, 255],
#         [102, 179, 255],
#         [102, 179, 255]],
#
#        ...,
#
#        [[183, 228, 249],
#         [183, 228, 249],
#         [183, 228, 249],
#         ...,
#         [235, 206, 135],
#         [235, 206, 135],
#         [235, 206, 135]],
#
#        [[183, 228, 249],
#         [183, 228, 249],
#         [183, 228, 249],
#         ...,
#         [235, 206, 135],
#         [235, 206, 135],
#         [235, 206, 135]],
#
#        [[183, 228, 249],
#         [183, 228, 249],
#         [183, 228, 249],
# ...

# %%
cv2.imwrite("beachimage.jpg",image)
# Out:
# True

# %%
cv2.

# %%
plot.imsave('beach.jpg',image)

# %%
plot.im1show(image)

# %% [markdown]
# ## Task4.2

# %% [markdown]
# ==> Take 2 image crop some part of both image and swap it

# %%
image1 = cv2.imread('wiz.jpg')
image1 = cv2.cvtColor(image1,cv2.COLOR_BGR2RGB)
image2 = cv2.imread('snoop.jpg')
image2 = cv2.cvtColor(image2,cv2.COLOR_BGR2RGB)

# %%
plot.imshow(image1)

# %%
plot.imshow(image2)

# %%
image1_crop = image1[200:630,300:640,:].copy()
plot.imshow(image1_crop)

# %%
image2_crop = image2[50:480,300:640,:].copy()
plot.imshow(image2_crop)

# %%
image1[200:630,300:640,:] = image2_crop
plot.imshow(image1)

# %%
image2[50:480,300:640,:] = image1_crop
plot.imshow(image2)

# %%
plot.imshow(image1)

# %%
plot.imshow(image2)

# %% [markdown]
# ## Task 4.3

# %% [markdown]
# ==> Take 2 image and combine it to form single image. For example collage

# %%
plot.imshow(image1_crop)

# %%
plot.imshow(image2_crop)

# %%
Combine_image = np.hstack([image1_crop,image2_crop])

# %%
plot.imshow(Combine_image)
